# %%
import pandas as pd
import os
from sklearn.preprocessing import StandardScaler
import sklearn

# %%
pwd = os.getcwd()
filepath = os.path.join(pwd,"wine.csv")

# %%
data_import = pd.read_csv(filepath)
data_import
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1596                 29.0                  40.0  0.99574  3.42       0.75
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality
# 0         9.4        5
# 1         9.8        5
# 2         9.8        5
# 3         9.8        6
# 4         9.4        5
# ...       ...      ...
# 1594     10.5        5
# 1595     11.2        6
# 1596     11.0        6
# 1597     10.2        5
# 1598     11.0        6
#
# [1599 rows x 12 columns]

# %%
data_import["quality"].hist()
# Out:
# <Axes: >

# %%
y = data_import["quality"]> 5
y
# Out:
# 0       False
# 1       False
# 2       False
# 3        True
# 4       False
#         ...
# 1594    False
# 1595     True
# 1596     True
# 1597    False
# 1598     True
# Name: quality, Length: 1599, dtype: bool

# %%
X = data_import.iloc[:,:-1]
X
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1596                 29.0                  40.0  0.99574  3.42       0.75
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol
# 0         9.4
# 1         9.8
# 2         9.8
# 3         9.8
# 4         9.4
# ...       ...
# 1594     10.5
# 1595     11.2
# 1596     11.0
# 1597     10.2
# 1598     11.0
#
# [1599 rows x 11 columns]

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X,y,train_size=0.2,random_state=42)
X_train
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1019            7.0             0.500         0.14             1.8      0.078
# 1336            6.0             0.500         0.00             1.4      0.057
# 959             8.0             0.590         0.05             2.0      0.089
# 1517            6.5             0.530         0.06             2.0      0.063
# 283             8.9             0.400         0.32             5.6      0.087
# ...             ...               ...          ...             ...        ...
# 1130            9.1             0.600         0.00             1.9      0.058
# 1294            8.2             0.635         0.10             2.1      0.073
# 860             7.2             0.620         0.06             2.7      0.077
# 1459            7.9             0.200         0.35             1.7      0.054
# 1126            5.8             0.290         0.26             1.7      0.063
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 1019                 10.0                  23.0  0.99636  3.53       0.61
# 1336                 15.0                  26.0  0.99448  3.36       0.45
# 959                  12.0                  32.0  0.99735  3.36       0.61
# 1517                 29.0                  44.0  0.99489  3.38       0.83
# 283                  10.0                  47.0  0.99910  3.38       0.77
# ...                   ...                   ...      ...   ...        ...
# 1130                  5.0                  10.0  0.99770  3.18       0.63
# 1294                 25.0                  60.0  0.99638  3.29       0.75
# 860                  15.0                  85.0  0.99746  3.51       0.54
# 1459                  7.0                  15.0  0.99458  3.32       0.80
# 1126                  3.0                  11.0  0.99150  3.39       0.54
#
#       alcohol
# 1019     10.4
# 1336      9.5
# 959      10.0
# 1517     10.3
# 283      10.5
# ...       ...
# 1130     10.4
# 1294     10.9
# 860       9.5
# 1459     11.9
# 1126     13.5
#
# [319 rows x 11 columns]

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

scaled_X_train = scaler.fit_transform(X_train)
scaled_X_train
# Out:
# array([[-0.7701434 , -0.18573034, -0.65077046, ...,  1.43602923,
#         -0.27620939, -0.11985817],
#        [-1.36099415, -0.18573034, -1.32776577, ...,  0.31065546,
#         -1.13269342, -0.97728212],
#        [-0.17929264,  0.33323006, -1.08598173, ...,  0.31065546,
#         -0.27620939, -0.50093548],
#        ...,
#        [-0.65197325,  0.50621685, -1.03762493, ...,  1.30363231,
#         -0.65092115, -0.97728212],
#        [-0.23837772, -1.91559832,  0.36472251, ...,  0.04586163,
#          0.7408654 ,  1.30918174],
#        [-1.4791643 , -1.39663793, -0.07048876, ...,  0.50925083,
#         -0.65092115,  2.83349098]])

# %%
scaled_X_test = scaler.transform(X_test)
scaled_X_test
# Out:
# array([[-0.35654787,  0.16024326, -0.94091131, ..., -0.48372603,
#         -0.00855813, -0.88201279],
#        [-0.29746279, -0.18573034, -0.50570004, ...,  0.50925083,
#         -0.97210267, -0.97728212],
#        [ 1.4160044 ,  0.79452818, -0.263916  , ..., -0.2189322 ,
#          1.70440994, -0.59620481],
#        ...,
#        [-0.47471802,  0.10258099, -0.16720238, ...,  0.90644157,
#          0.6338049 , -0.97728212],
#        [-0.65197325, -0.07040581, -0.98926812, ...,  0.04586163,
#          0.79439565, -0.88201279],
#        [-0.17929264, -1.4543002 ,  0.79993378, ...,  0.31065546,
#         -0.00855813,  0.64229645]])

# %%
def preprocessing_function(X,y):
    X_train, X_test, y_train, y_test = train_test_split(X,y,train_size=0.2,random_state=42)

    scaled_X_train = scaler.fit_transform(X_train)
    scaled_X_test = scaler.transform(X_test)

    return scaled_X_train,scaled_X_test,y_train,y_test

# %% [markdown]
# #### Classifier

# %%
from sklearn.svm import SVC

svc_clf = SVC()
svc_clf.fit(scaled_X_train,y_train)
# Out:
# SVC()

# %%
svc_clf_predictions = svc_clf.predict(scaled_X_tested)
svc_clf_predictions
# Out:
# array([False, False,  True, ..., False,  True,  True])

# %%
from sklearn.metrics import confusion_matrix, accuracy_score,precision_score,recall_score
import matplotlib.pyplot as plt


confusion_matrix(y_test,svc_clf_predictions)
plt.matshow(confusion_matrix(y_test,svc_clf_predictions))

# %%
accuracy_score(y_test,svc_clf_predictions)
# Out:
# 0.72421875

# %%
precision_score(y_test,svc_clf_predictions)
# Out:
# 0.7439393939393939

# %%
recall_score(y_test,svc_clf_predictions)
# Out:
# 0.7274074074074074

# %%
def algo_accuracy(y_test, predictions):
    conf_matrix = confusion_matrix(y_test, predictions)
    accuracy = accuracy_score(y_test, predictions)
    precision = precision_score(y_test, predictions)
    recall = recall_score(y_test, predictions)

    return conf_matrix, accuracy, precision, recall

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestClassifier

param_grid = [
    # try 12 (3×4) combinations of hyperparameters
    {'n_estimators': [3, 10, 30], 'max_features': [2, 4, 6, 8]},
    # then try 6 (2×3) combinations with bootstrap set as False
    {'bootstrap': [False], 'n_estimators': [3, 10], 'max_features': [2, 3, 4]},
  ]
rfc = RandomForestClassifier()

# train across 5 folds, that's a total of (12+6)*5=90 rounds of training 
grid_search = GridSearchCV(rfc, param_grid, cv=5,
                           scoring='accuracy',
                           return_train_score=True)
grid_search.fit(scaled_X_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestClassifier(),
#              param_grid=[{'max_features': [2, 4, 6, 8],
#                           'n_estimators': [3, 10, 30]},
#                          {'bootstrap': [False], 'max_features': [2, 3, 4],
#                           'n_estimators': [3, 10]}],
#              return_train_score=True, scoring='accuracy')

# %%
rfc_clf = grid_search.best_estimator_
rfc_clf
# Out:
# RandomForestClassifier(max_features=8, n_estimators=30)

# %%
rfc_predictions = rfc_clf.predict(scaled_X_test)
rfc_predictions
# Out:
# array([False, False,  True, ..., False, False,  True])

# %%
algo_accuracy(y_test, rfc_predictions)
# Out:
# (array([[456, 149],
#         [201, 474]]),
#  0.7265625,
#  0.7608346709470305,
#  0.7022222222222222)
